# %%
import pandas as pd

# %%
b_df = pd.read_csv("data/bolly_songs.csv")

# %%
b_df.head()
# Out:
#           Song-Name                                    Singer/Artists  \
# 0       Aankh Marey               Kumar Sanu, Mika Singh, Neha Kakkar
# 1         Coca Cola                          Neha Kakkar, Tony Kakkar
# 2  Apna Time Aayega                                     Ranveer Singh
# 3            Mungda             Jyotica Tangri, Shaan, Subhro Ganguly
# 4          Tere Bin  Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
#
#                     Genre    Album/Movie User-Rating
# 0          BollywoodDance         Simmba      8.8/10
# 1  BollywoodDanceRomantic    Luka Chuppi      9.0/10
# 2          BollywoodDance      Gully Boy      9.7/10
# 3          BollywoodDance  Total Dhamaal      9.1/10
# 4       BollywoodRomantic         Simmba      9.2/10

# %% [markdown]
# ### Data Cleaning

# %%
b_df.isnull().sum()
# Out:
# Song-Name          0
# Singer/Artists    10
# Genre              0
# Album/Movie        3
# User-Rating        0
# dtype: int64

# %%
b_df.dropna(inplace= True) # modifies the current database instead of creating new one

# %%
b_df.isnull().sum()
# Out:
# Song-Name         0
# Singer/Artists    0
# Genre             0
# Album/Movie       0
# User-Rating       0
# dtype: int64

# %%
b_df.duplicated().sum()
# Out:
# 16

# %%
b_df = b_df.drop_duplicates()

# %%
b_df.duplicated().sum()
# Out:
# 0

# %%
b_df.head()
# Out:
#           Song-Name                                    Singer/Artists  \
# 0       Aankh Marey               Kumar Sanu, Mika Singh, Neha Kakkar
# 1         Coca Cola                          Neha Kakkar, Tony Kakkar
# 2  Apna Time Aayega                                     Ranveer Singh
# 3            Mungda             Jyotica Tangri, Shaan, Subhro Ganguly
# 4          Tere Bin  Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
#
#                     Genre    Album/Movie User-Rating
# 0          BollywoodDance         Simmba      8.8/10
# 1  BollywoodDanceRomantic    Luka Chuppi      9.0/10
# 2          BollywoodDance      Gully Boy      9.7/10
# 3          BollywoodDance  Total Dhamaal      9.1/10
# 4       BollywoodRomantic         Simmba      9.2/10

# %%
b_df['User-Rating']
# Out:
# 0       8.8/10
# 1       9.0/10
# 2       9.7/10
# 3       9.1/10
# 4       9.2/10
#          ...
# 2415    6.2/10
# 2416    7.2/10
# 2417    7.5/10
# 2418    6.5/10
# 2419    6.6/10
# Name: User-Rating, Length: 2391, dtype: object

# %%
l = []
for i in b_df['User-Rating']:
    l.append(i[:3])
l
# Out:
# ['8.8',
#  '9.0',
#  '9.7',
#  '9.1',
#  '9.2',
#  '9.1',
#  '9.2',
#  '9.5',
#  '9.2',
#  '9.6',
#  '8.8',
#  '8.4',
#  '9.1',
#  '9.2',
#  '9.0',
#  '9.7',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.1',
#  '9.2',
#  '9.2',
#  '9.5',
#  '8.6',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.2',
#  '9.5',
#  '9.4',
#  '8.7',
#  '9.3',
#  '9.3',
#  '9.5',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.1',
#  '8.4',
#  '8.4',
#  '8.8',
#  '9.2',
#  '9.2',
#  '9.6',
#  '9.6',
#  '9.0',
#  '9.1',
#  '8.5',
#  '9.5',
#  '8.5',
#  '9.7',
#  '8.9',
#  '9.6',
#  '8.5',
#  '9.1',
#  '8.7',
#  '8.6',
#  '9.3',
#  '9.7',
#  '8.9',
#  '9.0',
#  '9.0',
#  '9.3',
#  '9.3',
#  '9.1',
#  '9.0',
#  '9.7',
#  '9.2',
#  '9.1',
#  '9.0',
#  '8.9',
#  '9.5',
#  '9.5',
#  '9.7',
#  '9.0',
#  '8.1',
#  '8.1',
#  '9.5',
#  '9.1',
#  '8.6',
#  '9.4',
#  '9.0',
#  '9.0',
#  '9.6',
#  '9.3',
#  '9.0',
#  '9.2',
#  '9.3',
#  '9.1',
#  '8.6',
#  '9.5',
#  '9.5',
#  '9.0',
#  '9.4',
#  '9.2',
#  '9.6',
#  '9.3',
#  '7.7',
#  '9.2',
#  '9.3',
# ...

# %%
b_df['User-Rating'] = l
b_df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# 1                             Neha Kakkar, Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri, Shaan, Subhro Ganguly
# 4     Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# ...

# %%
b_df['Album/Movie'] = b_df['Album/Movie'].str.replace(' ','')
b_df['Singer/Artists'] = b_df['Singer/Artists'].str.replace(' ','')
b_df['Singer/Artists'] = b_df['Singer/Artists'].str.replace(',',' ')
b_df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                  Singer/Artists                   Genre  \
# 0                KumarSanu MikaSingh NehaKakkar          BollywoodDance
# 1                         NehaKakkar TonyKakkar  BollywoodDanceRomantic
# 2                                  RanveerSingh          BollywoodDance
# 3             JyoticaTangri Shaan SubhroGanguly          BollywoodDance
# 4     AseesKaur RahatFatehAliKhan TanishkBagchi       BollywoodRomantic
# ...

# %%
b_df['tags'] = b_df['Singer/Artists'] + ' ' + b_df['Genre'] + ' ' + b_df['Album/Movie'] + ' ' + b_df['User-Rating']

# %%
b_df['tags'][0]
# Out:
# 'KumarSanu MikaSingh NehaKakkar BollywoodDance Simmba 8.8'

# %%
b_df.rename(columns={'Singer/Artists' : 'artist'}, inplace= True)

# %%
new_df = b_df[['Song-Name','tags','artist']] 
new_df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags  \
# 0     KumarSanu MikaSingh NehaKakkar BollywoodDance ...
# 1     NehaKakkar TonyKakkar BollywoodDanceRomantic L...
# 2              RanveerSingh BollywoodDance GullyBoy 9.7
# 3     JyoticaTangri Shaan SubhroGanguly BollywoodDan...
# 4     AseesKaur RahatFatehAliKhan TanishkBagchi Boll...
# ...                                                 ...
# 2415                  Mukesh BollywoodDance Sasural 6.2
# ...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x : x.lower()) 
new_df
# Out:
# C:\Users\naren\AppData\Local\Temp\ipykernel_7080\604541391.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x : x.lower())
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 2000)

# %%
vectors= cv.fit_transform(new_df['tags']).toarray()

# %%
vectors.shape
# Out:
# (2391, 1697)

# %%
cv.get_feature_names_out()
# Out:
# array(['13', '1920', '1921', ..., 'zindaginamilegidobara',
#        'zindagiyehzindagi', 'zubeengarg'], dtype=object)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similar = cosine_similarity(vectors)

# %%
similar[0]
# Out:
# array([1.        , 0.2236068 , 0.25819889, ..., 0.2236068 , 0.25819889,
#        0.25819889])

# %% [markdown]
# ### Recommender function

# %%
new_df.rename(columns={'Song-Name' : 'song'}, inplace= True)
# Out:
# C:\Users\naren\AppData\Local\Temp\ipykernel_7080\382684592.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename(columns={'Song-Name' : 'song'}, inplace= True)

# %%
new_df.head()
# Out:
#                song                                               tags  \
# 0       Aankh Marey  kumarsanu mikasingh nehakakkar bollywooddance ...
# 1         Coca Cola  nehakakkar tonykakkar bollywooddanceromantic l...
# 2  Apna Time Aayega           ranveersingh bollywooddance gullyboy 9.7
# 3            Mungda  jyoticatangri shaan subhroganguly bollywooddan...
# 4          Tere Bin  aseeskaur rahatfatehalikhan tanishkbagchi boll...
#
#                                       artist
# 0             KumarSanu MikaSingh NehaKakkar
# 1                      NehaKakkar TonyKakkar
# 2                               RanveerSingh
# 3          JyoticaTangri Shaan SubhroGanguly
# 4  AseesKaur RahatFatehAliKhan TanishkBagchi

# %%
def recommender(song_name):
    idx = new_df[new_df['song']==song_name].index[0]
    distance = sorted(list(enumerate(similar[idx])), reverse = True, key= lambda x:x[1])
    Song = []
    for s_id in distance[1:5]: # if I change the value here the number of recommendations changes
        Song.append(new_df.iloc[s_id[0]].song)
    return Song

# %%
recommender("Tere Bin")
# Out:
# ['Sanu Ek Pal Chain', 'Jag Ghoomeya', 'Nit Khair Manga', 'Lag Ja Gale']

# %%
import pickle

# %%
pickle.dump(similar, open("data/bolly_similarity.pkl", "wb"))

# %%
pickle.dump(new_df, open("data/bolly_df.pkl", "wb"))
